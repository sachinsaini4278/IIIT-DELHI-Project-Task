# %% [markdown]
# # Python script which can fetch all the tweets done by midas@IIITD twitter handle

# %% [markdown]
# Import important libraraies

# %%
import tweepy
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# %%
# Consumer keys and access tokens, used for OAuth
access_token = '1114533013788848129-fNIa8YRNAwH2GX7p8mCjD5csTYYmZG '
consumer_key="Lzi4KrNQNOwozznjyEDNvdFxy"
consumer_secret="Q9jddzfAyFie1MXZI3HzkTzqOUQ4kHf7SWDMRFN7NxFmLdbmOx"
access_token_secret='RA0HeAEE5YqafVU3X6w7YKX8ZCxEEaFvswYz9gyNKM6xv'

# OAuth process, using the keys and tokens
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
 
# Creation of the actual interface, using authentication
api = tweepy.API(auth)

# %%
# Create the api endpoint

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
api = tweepy.API(auth)

# Mention the maximum number of tweets that you want to be extracted.

maximum_number_of_tweets_to_be_extracted = 500
count = 0
# Mention the hashtag that you want to look out for

#hashtag = input('Enter the hashtag you want to scrape- ')
hashtag= '@midasIIITD'
for tweet in tweepy.Cursor(api.search, q='#' + hashtag,rpp=100).items(maximum_number_of_tweets_to_be_extracted):
    with open('tweets_with_hashtag_' + hashtag + '.txt', 'a') as the_file:
        the_file.write(str(tweet.text.encode('utf-8')) + '\n')
        #Tweet text
        print(tweet.text)
        print('time and date = ', tweet.created_at)
        #count retweets
        print('No of Retweets',tweet.retweet_count)
        print('No of likes/favorite',tweet.favorite_count)
        count+=1
        #chack for image
        

print ('Extracted ' + str(count) + ' tweets with hashtag #' + hashtag)
# Out:
# RT @midasIIITD: Many Congratulations to @midasIIITD student, Shagun Uppal @shagunuppls, on getting selected for the summer internship in th…
# time and date =  2019-04-08 12:32:22
# No of Retweets 2
# No of likes/favorite 0
# RT @midasIIITD: Many Congratulations to @midasIIITD student, Shagun Uppal @shagunuppls, on getting selected for the summer internship in th…
# time and date =  2019-04-08 07:09:00
# No of Retweets 2
# No of likes/favorite 0
# Many Congratulations to @midasIIITD student, Shagun Uppal @shagunuppls, on getting selected for the summer internsh… https://t.co/bzhiSm4zuB
# time and date =  2019-04-08 07:08:12
# No of Retweets 2
# No of likes/favorite 13
# @midasIIITD thanks all students who have appeared for the interview yesterday. We will announce the interview resul… https://t.co/qxESgZPtKJ
# time and date =  2019-04-08 03:27:42
# No of Retweets 0
# No of likes/favorite 5
# @midasIIITD I have already uploaded the solutions in my GitHub in two different repos,
# ...

# %% [markdown]
# # check whether tweet conatains image or not

# %%
import requests
timeline = api.user_timeline(count=341, screen_name = "midasIIITD") 
count = 0
for tweet in timeline:
    for media in tweet.entities.get("media",[{}]):
        #print (media)
        #checks if there is any media-entity
        if media.get("type",None) == "photo":# checks if the entity is of the type "photo"
            image_content=requests.get(media["media_url"])
            print ("yes")
        else:
            print("None")
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# yes
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# yes
# None
# None
# None
# None
# None
# None
# None
# yes
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# yes
# None
# yes
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# yes
# None
# None
# None
# None
# None
# None
# None
# yes
# yes
# None
# None
# None
# None
# None
# None
# yes
# None
# None
# None
# ...
